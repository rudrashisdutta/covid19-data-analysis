# %% [markdown]
# <h1 align="center" style="font-size:4em;">GROUP-3 DA MINOR PROJECT</h1>

# %% [markdown]
# # COVID 19 DATA ANALYSIS
#
# **Dataset Used:  [COVID-19 DATASET TILL 19th JAN,2023]()**
# <br/>
# **[Dataset Source](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/L20LOT)**
# <br/>
# ### **[Source Code]()**

# %% [markdown]
# ## Importing all required libraries.
#
# pandas: For Managing and performing operations on the dataset <br/>
# seaborn & matplotlib: For Analytic Plots

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset using pandas and viewing information about it.
#
# Dataset: An integrated version of the original dataset was imported for analyses.

# %%
data = pd.read_excel('covid_19_data.xlsx')
data
# Out:
#      SL.NO.              Region  Confirmed   Deaths  Recovered  \
# 0         1         Afghanistan   51031207  2215477   18289880
# 1         2             Albania   59048423  1021313   22652652
# 2         3             Algeria   71994050  2062443   25670233
# 3         4             Andorra    6287389    62815    3085649
# 4         5              Angola   17845808   440176    5895800
# ..      ...                 ...        ...      ...        ...
# 191     192             Vietnam  172110189  3596323    1261448
# 192     193  West Bank and Gaza  133713308  1420594   57608773
# 193     194               Yemen    2980408   627605     772497
# 194     195              Zambia   60389443   975400   21852796
# 195     196            Zimbabwe   35620942  1164276    8779035
#
#                                     Date
# 0    COVID-19 DATASET TILL 19th JAN,2023
# 1    COVID-19 DATASET TILL 19th JAN,2023
# 2    COVID-19 DATASET TILL 19th JAN,2023
# 3    COVID-19 DATASET TILL 19th JAN,2023
# ...

# %%
data.nunique()
# Out:
# SL.NO.       196
# Region       196
# Confirmed    196
# Deaths       188
# Recovered    192
# Date           1
# dtype: int64

# %% [markdown]
# Dropped column Date because the value was same constant.

# %%
data.drop('Date', axis=1, inplace=True)
data
# Out:
#      SL.NO.              Region  Confirmed   Deaths  Recovered
# 0         1         Afghanistan   51031207  2215477   18289880
# 1         2             Albania   59048423  1021313   22652652
# 2         3             Algeria   71994050  2062443   25670233
# 3         4             Andorra    6287389    62815    3085649
# 4         5              Angola   17845808   440176    5895800
# ..      ...                 ...        ...      ...        ...
# 191     192             Vietnam  172110189  3596323    1261448
# 192     193  West Bank and Gaza  133713308  1420594   57608773
# 193     194               Yemen    2980408   627605     772497
# 194     195              Zambia   60389443   975400   21852796
# 195     196            Zimbabwe   35620942  1164276    8779035
#
# [196 rows x 5 columns]

# %%
data.shape
# Out:
# (196, 5)

# %%
data.columns
# Out:
# Index(['SL.NO.', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
len(data)
# Out:
# 196

# %%
data.describe()
# Out:
#           SL.NO.     Confirmed        Deaths     Recovered
# count  196.00000  1.960000e+02  1.960000e+02  1.960000e+02
# mean    98.50000  4.115738e+08  8.906652e+06  1.198544e+08
# std     56.72448  1.539843e+09  3.023285e+07  4.485847e+08
# min      1.00000  8.300000e+01  0.000000e+00  0.000000e+00
# 25%     49.75000  5.907076e+06  8.366525e+04  1.653848e+06
# 50%     98.50000  5.498204e+07  7.285665e+05  1.126299e+07
# 75%    147.25000  1.943240e+08  3.791982e+06  6.495202e+07
# max    196.00000  1.615147e+10  2.873332e+08  4.859388e+09

# %%
data.count()
# Out:
# SL.NO.       196
# Region       196
# Confirmed    196
# Deaths       196
# Recovered    196
# dtype: int64

# %%
data.isnull().sum()
# Out:
# SL.NO.       0
# Region       0
# Confirmed    0
# Deaths       0
# Recovered    0
# dtype: int64

# %%
data.corr()
# Out:
#              SL.NO.  Confirmed    Deaths  Recovered
# SL.NO.     1.000000   0.059099  0.044623  -0.055717
# Confirmed  0.059099   1.000000  0.937915   0.695254
# Deaths     0.044623   0.937915  1.000000   0.677210
# Recovered -0.055717   0.695254  0.677210   1.000000

# %%
data.drop(['SL.NO.','Region'], axis=1).corr()
# Out:
#            Confirmed    Deaths  Recovered
# Confirmed   1.000000  0.937915   0.695254
# Deaths      0.937915  1.000000   0.677210
# Recovered   0.695254  0.677210   1.000000

# %%
sns.set(style = 'whitegrid')

# %%
sns.heatmap(data.drop(['SL.NO.','Region'], axis=1), cbar=False)
plt.show()

# %%
sns.heatmap(data.drop(['SL.NO.','Region'], axis=1).corr(), cbar=False)
plt.show()

# %%
plt.figure(figsize = (15, 8))
sns.barplot(x = 'Region', y = 'Confirmed', data = data)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize = (15, 8))
sns.barplot(x = 'Region', y = 'Deaths', data = data)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize = (15, 8))
sns.barplot(x = 'Region', y = 'Recovered', data = data)
plt.plot()
# Out:
# []

# %% [markdown]
# ## Showing the number of Confirmed cases, Deaths and Recoveries in each Region.

# %%
data.groupby('Region').sum().head(50)
# Out:
#                           SL.NO.   Confirmed     Deaths   Recovered
# Region
# Afghanistan                    1    51031207    2215477    18289880
# Albania                        2    59048423    1021313    22652652
# Algeria                        3    71994050    2062443    25670233
# Andorra                        4     6287389      62815     3085649
# Angola                         5    17845808     440176     5895800
# Antigua and Barbuda            6      806333      21770      191813
# Argentina                      7  1711512286   37719874   711610324
# Armenia                        8   107375016    2138672    51634388
# Australia                      9    56213092     608003     8821094
# Austria                       10   299297164    4388005   131744371
# Azerbaijan                    11   162192925    2213147    68764706
# Bahamas                       12     6663560     160009     2484156
# Bahrain                       13    98227900     445040    48612087
# ...

# %%
pd.DataFrame(data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20))
# Out:
#                   Confirmed
# Region
# US              16151470670
# India           10985565305
# Brazil           7531624557
# Russia           2713220003
# United Kingdom   2695867498
# France           2590479705
# Turkey           2316282519
# Spain            1808838995
# Italy            1786552423
# Argentina        1711512286
# Germany          1646933716
# Colombia         1643501444
# Iran             1574862348
# Mexico           1256655745
# Indonesia        1129478540
# Poland           1127972579
# South Africa      985252847
# Ukraine           979452424
# Peru              871972690
# Netherlands       759778450

# %%
pd.DataFrame(data.groupby('Region')['Confirmed'].sum())
# Out:
#                     Confirmed
# Region
# Afghanistan          51031207
# Albania              59048423
# Algeria              71994050
# Andorra               6287389
# Angola               17845808
# ...                       ...
# Vietnam             172110189
# West Bank and Gaza  133713308
# Yemen                 2980408
# Zambia               60389443
# Zimbabwe             35620942
#
# [196 rows x 1 columns]

# %% [markdown]
# ## Removing all the records where Confirmed case is less than 100.

# %%
pd.DataFrame(data.Confirmed < 10)
# Out:
#      Confirmed
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 191      False
# 192      False
# 193      False
# 194      False
# 195      False
#
# [196 rows x 1 columns]

# %%
data[data.Confirmed < 100]
# Out:
#      SL.NO. Region  Confirmed  Deaths  Recovered
# 178     179  Tonga         83       0          0

# %%
data[~(data.Confirmed < 100)]
# Out:
#      SL.NO.              Region  Confirmed   Deaths  Recovered
# 0         1         Afghanistan   51031207  2215477   18289880
# 1         2             Albania   59048423  1021313   22652652
# 2         3             Algeria   71994050  2062443   25670233
# 3         4             Andorra    6287389    62815    3085649
# 4         5              Angola   17845808   440176    5895800
# ..      ...                 ...        ...      ...        ...
# 191     192             Vietnam  172110189  3596323    1261448
# 192     193  West Bank and Gaza  133713308  1420594   57608773
# 193     194               Yemen    2980408   627605     772497
# 194     195              Zambia   60389443   975400   21852796
# 195     196            Zimbabwe   35620942  1164276    8779035
#
# [195 rows x 5 columns]

# %%
data = data[~(data.Confirmed < 100)]
data
# Out:
#      SL.NO.              Region  Confirmed   Deaths  Recovered
# 0         1         Afghanistan   51031207  2215477   18289880
# 1         2             Albania   59048423  1021313   22652652
# 2         3             Algeria   71994050  2062443   25670233
# 3         4             Andorra    6287389    62815    3085649
# 4         5              Angola   17845808   440176    5895800
# ..      ...                 ...        ...      ...        ...
# 191     192             Vietnam  172110189  3596323    1261448
# 192     193  West Bank and Gaza  133713308  1420594   57608773
# 193     194               Yemen    2980408   627605     772497
# 194     195              Zambia   60389443   975400   21852796
# 195     196            Zimbabwe   35620942  1164276    8779035
#
# [195 rows x 5 columns]

# %% [markdown]
# ## Showing Regions with maximum number of Confirmed cases.

# %%
pd.DataFrame(data.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(50))
# Out:
#                         Confirmed
# Region
# US                    16151470670
# India                 10985565305
# Brazil                 7531624557
# Russia                 2713220003
# United Kingdom         2695867498
# France                 2590479705
# Turkey                 2316282519
# Spain                  1808838995
# Italy                  1786552423
# Argentina              1711512286
# Germany                1646933716
# Colombia               1643501444
# Iran                   1574862348
# Mexico                 1256655745
# Indonesia              1129478540
# Poland                 1127972579
# South Africa            985252847
# Ukraine                 979452424
# Peru                    871972690
# Netherlands             759778450
# Philippines             690143760
# Czechia                 677823440
# Chile                   623847610
# Iraq                    617311171
# Canada                  588850123
# Belgium                 510614905
# ...

# %% [markdown]
# ## Showing Regions with minimum number of Death cases.

# %%
pd.DataFrame(data.groupby('Region').Deaths.sum().sort_values(ascending=True).head(50))
# Out:
#                                   Deaths
# Region
# Holy See                               0
# Summer Olympics 2020                   0
# Marshall Islands                       0
# Samoa                                  0
# Kiribati                               0
# Micronesia                             0
# Palau                                  0
# Solomon Islands                        0
# Vanuatu                              274
# Bhutan                               727
# MS Zaandam                          1318
# Saint Kitts and Nevis               3259
# Dominica                            4392
# Burundi                             7899
# Diamond Princess                    8807
# Saint Vincent and the Grenadines   10271
# Eritrea                            11643
# Brunei                             12088
# Monaco                             12499
# Iceland                            15757
# New Zealand                        17451
# Sao Tome and Principe              18718
# ...

# %% [markdown]
# ## Showing Confirmed Cases, Deaths nd Recovered Cases reported from India, Yemen and US.

# %%
data[data.Region == 'India']
# Out:
#     SL.NO. Region    Confirmed     Deaths   Recovered
# 79      80  India  10985565305  147758233  4859387857

# %%
data[data.Region == 'Yemen']
# Out:
#      SL.NO. Region  Confirmed  Deaths  Recovered
# 193     194  Yemen    2980408  627605     772497

# %%
data[data.Region == 'US']
# Out:
#      SL.NO. Region    Confirmed     Deaths  Recovered
# 182     183     US  16151470670  287333202  496971828

# %% [markdown]
# ## Sorting the entire Dataset w.r.t. Number of Confirmed Cases in ascending order.

# %%
pd.DataFrame(data.sort_values(by=['Confirmed'], ascending=True))
# Out:
#      SL.NO.          Region    Confirmed     Deaths   Recovered
# 116     117      Micronesia          364          0         188
# 91       92        Kiribati          491          0           0
# 149     150           Samoa         1186          0         561
# 189     190         Vanuatu         1553        274         453
# 134     135           Palau         1683          0           0
# ..      ...             ...          ...        ...         ...
# 186     187  United Kingdom   2695867498   61205102     3447801
# 144     145          Russia   2713220003   67002875  1128064202
# 23       24          Brazil   7531624557  208472646  3412350387
# 79       80           India  10985565305  147758233  4859387857
# 182     183              US  16151470670  287333202   496971828
#
# [195 rows x 5 columns]

# %% [markdown]
# ## Sorting the entire Dataset w.r.t. Number of Recovered Cases in descending order.

# %%
pd.DataFrame(data.sort_values(by=['Recovered'], ascending=False))
# Out:
#      SL.NO.                Region    Confirmed     Deaths   Recovered
# 79       80                 India  10985565305  147758233  4859387857
# 23       24                Brazil   7531624557  208472646  3412350387
# 144     145                Russia   2713220003   67002875  1128064202
# 181     182                Turkey   2316282519   21822789   919259007
# 85       86                 Italy   1786552423   56829282   759237934
# ..      ...                   ...          ...        ...         ...
# 116     117            Micronesia          364          0         188
# 169     170                Sweden    417614729    6834806           0
# 167     168  Summer Olympics 2020       140578          0           0
# 134     135                 Palau         1683          0           0
# 91       92              Kiribati          491          0           0
#
# [195 rows x 5 columns]

# %% [markdown]
# ## Displaying the death and recovery percentage for all the regions.

# %% [markdown]
# Death Percent

# %%
pd.DataFrame([data['Region'],(data['Deaths']/data['Confirmed'])*100], index=['Region', 'Death percent'])
# Out:
#                        0         1         2         3         4    \
# Region         Afghanistan   Albania   Algeria   Andorra    Angola
# Death percent     4.341416  1.729619  2.864741  0.999063  2.466551
#
#                                5          6         7          8         9    \
# Region         Antigua and Barbuda  Argentina   Armenia  Australia   Austria
# Death percent             2.699877   2.203892  1.991778   1.081604  1.466103
#
#                ...             186       187         188        189  \
# Region         ...  United Kingdom   Uruguay  Uzbekistan    Vanuatu
# Death percent  ...         2.27033  1.475298    0.729455  17.643271
#
#                      190       191                 192        193       194  \
# Region         Venezuela   Vietnam  West Bank and Gaza      Yemen    Zambia
# Death percent    1.12099  2.089547            1.062418  21.057687  1.615183
#
#                     195
# Region         Zimbabwe
# Death percent  3.268515
#
# ...

# %% [markdown]
# Recovery Percent

# %%
pd.DataFrame([data['Region'],(data['Recovered']/data['Confirmed'])*100], index=['Region', 'Recovery percent'])
# Out:
#                           0         1          2          3          4    \
# Region            Afghanistan   Albania    Algeria    Andorra     Angola
# Recovery percent    35.840579  38.36284  35.656048  49.076795  33.037451
#
#                                   5          6          7          8    \
# Region            Antigua and Barbuda  Argentina    Armenia  Australia
# Recovery percent            23.788311  41.577868  48.087898  15.692241
#
#                         9    ...             186        187         188  \
# Region              Austria  ...  United Kingdom    Uruguay  Uzbekistan
# Recovery percent  44.017915  ...        0.127892  33.901428   47.229543
#
#                        189        190      191                 192        193  \
# Region             Vanuatu  Venezuela  Vietnam  West Bank and Gaza      Yemen
# Recovery percent  29.16935  41.430218  0.73293           43.083799  25.919169
#
#                         194        195
# ...

# %% [markdown]
# ## Displaying the Death:Recovery ratio in all regions.

# %%
pd.DataFrame([data['Region'],data['Deaths']/data['Recovered']], index=['Region', 'Death:Recovery ratio'])
# Out:
#                               0         1         2         3         4    \
# Region                Afghanistan   Albania   Algeria   Andorra    Angola
# Death:Recovery ratio     0.121131  0.045086  0.080344  0.020357  0.074659
#
#                                       5          6        7          8    \
# Region                Antigua and Barbuda  Argentina  Armenia  Australia
# Death:Recovery ratio             0.113496   0.053006  0.04142   0.068926
#
#                            9    ...             186       187         188  \
# Region                 Austria  ...  United Kingdom   Uruguay  Uzbekistan
# Death:Recovery ratio  0.033307  ...       17.751924  0.043517    0.015445
#
#                            189        190       191                 192  \
# Region                 Vanuatu  Venezuela   Vietnam  West Bank and Gaza
# Death:Recovery ratio  0.604857   0.027057  2.850948            0.024659
#
#                            193       194       195
# ...
